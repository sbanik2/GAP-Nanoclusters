# %%
# !rm -r plots

# %%
import os
import shutil

# Path where original data is located
base_dir = "/global/cfs/cdirs/m4597/Suvo/GAP_all/calcdir"

# Where you run this script (destination root)
destination_root = os.path.join(os.getcwd(), "plots")
os.makedirs(destination_root, exist_ok=True)

# Go through each element directory in base_dir
for element in os.listdir(base_dir):
    element_dir = os.path.join(base_dir, element)
    supp_dir = os.path.join(element_dir, "supplementary_figs")
    
    if os.path.isdir(supp_dir):
        dest_dir = os.path.join(destination_root, element)
        os.makedirs(dest_dir, exist_ok=True)

        # Copy contents
        for item in os.listdir(supp_dir):
            src_path = os.path.join(supp_dir, item)
            dst_path = os.path.join(dest_dir, item)
            if os.path.isdir(src_path):
                shutil.copytree(src_path, dst_path, dirs_exist_ok=True)
            else:
                shutil.copy2(src_path, dst_path)

        print(f"[✓] Copied {element}")
    else:
        print(f"[✗] Skipping {element}: supplementary_figs not found")
# Out:
# [✓] Copied In
# [✓] Copied As
# [✓] Copied Nb
# [✓] Copied Sc
# [✓] Copied Co
# [✓] Copied Y
# [✓] Copied Cr
# [✓] Copied Sn
# [✓] Copied Hf
# [✓] Copied Cu
# [✓] Copied Pd
# [✓] Copied Mg
# [✓] Copied Pt
# [✓] Copied Mo
# [✓] Copied Rh
# [✓] Copied Zn
# [✓] Copied Be
# [✓] Copied P
# [✗] Skipping .ipynb_checkpoints: supplementary_figs not found
# [✓] Copied Te
# [✓] Copied Ag
# [✓] Copied W
# [✓] Copied Na
# [✓] Copied Ni
# [✓] Copied Au
# [✓] Copied Sb
# [✓] Copied Ca
# [✓] Copied Se
# [✓] Copied Sr
# [✓] Copied Cd
# [✓] Copied V
# [✓] Copied Mn
# [✓] Copied K
# [✓] Copied Rb
# [✓] Copied Ba
# [✓] Copied C
# [✓] Copied Bi
# [✓] Copied Re
# [✓] Copied Ru
# [✓] Copied Ge
# [✓] Copied Ta
# [✓] Copied Ti
# [✓] Copied Os
# [✓] Copied Tl
# [✓] Copied Li
# [✓] Copied B
# [✓] Copied Al
# [✓] Copied Fe
# [✓] Copied Ir
# [✓] Copied Si
# [✓] Copied Cs
# [✓] Copied Pb
# [✓] Copied S
# [✓] Copied Ga
# [✓] Copied Zr

# %%
import json

# %%
with open("../best_path.json") as infile:
    best_paths = json.load(infile)

# %%
elements = []
rcuts = []

for elm,item in  best_paths.items():
    with open(f"{item['best_path']}/param.txt", 'r') as file:
        rcut = float(file.readline().strip().split(',')[0])
    elements+=[elm]
    rcuts+=[rcut]

# %%
import os
import re


cutoffs = rcuts

# === Build element → rcut dictionary ===
rcut_dict = {elem: rcut for elem, rcut in zip(elements, cutoffs)}

# === Directory containing the HTML pages ===
pages_dir = "pages"

# === Regex pattern to locate rcut line ===
rcut_pattern = re.compile(r'(r<sub>cut</sub> \(GAP\):</strong>\s*)([\d.]+)( Å)')

# === Loop over each HTML file in the directory ===
for filename in os.listdir(pages_dir):
    if filename.endswith(".html"):
        element = filename.split(".")[0]
        file_path = os.path.join(pages_dir, filename)

        if element not in rcut_dict:
            print(f"[!] No cutoff value for {element}, skipping.")
            continue

        rcut_value = rcut_dict[element]
        new_line = r"\g<1>{:.2f}\g<3>".format(rcut_value)

        with open(file_path, "r") as f:
            content = f.read()

        # Replace using regex
        updated_content = re.sub(rcut_pattern, new_line, content)

        with open(file_path, "w") as f:
            f.write(updated_content)

        print(f"[✓] Updated {element} → rcut = {rcut_value:.2f} Å")
# Out:
# [✓] Updated Sb → rcut = 3.75 Å
# [✓] Updated In → rcut = 5.25 Å
# [✓] Updated P → rcut = 2.75 Å
# [✓] Updated Tl → rcut = 5.25 Å
# [✓] Updated W → rcut = 4.00 Å
# [✓] Updated Sn → rcut = 4.00 Å
# [✓] Updated Zn → rcut = 3.25 Å
# [✓] Updated Ga → rcut = 3.50 Å
# [✓] Updated Na → rcut = 6.25 Å
# [✓] Updated Al → rcut = 4.50 Å
# [✓] Updated Be → rcut = 3.50 Å
# [✓] Updated Si → rcut = 3.00 Å
# [✓] Updated Ag → rcut = 4.75 Å
# [✓] Updated Co → rcut = 4.00 Å
# [✓] Updated Hf → rcut = 4.75 Å
# [✓] Updated Mo → rcut = 3.25 Å
# [✓] Updated As → rcut = 3.25 Å
# [✓] Updated Ti → rcut = 3.75 Å
# [✓] Updated Fe → rcut = 3.25 Å
# [✓] Updated S → rcut = 3.00 Å
# [✓] Updated B → rcut = 2.25 Å
# [✓] Updated Ir → rcut = 3.50 Å
# [✓] Updated Au → rcut = 3.25 Å
# [✓] Updated Rh → rcut = 4.25 Å
# [✓] Updated Zr → rcut = 4.00 Å
# [✓] Updated Ge → rcut = 3.50 Å
# [✓] Updated Ru → rcut = 4.25 Å
# [✓] Updated Bi → rcut = 4.00 Å
# [✓] Updated Mg → rcut = 4.25 Å
# [✓] Updated Cs → rcut = 6.75 Å
# [✓] Updated Ca → rcut = 6.25 Å
# [✓] Updated Li → rcut = 4.50 Å
# [✓] Updated Y → rcut = 5.50 Å
# [✓] Updated Ta → rcut = 3.50 Å
# [✓] Updated Pt → rcut = 4.75 Å
# [✓] Updated Pb → rcut = 4.25 Å
# [✓] Updated Sc → rcut = 5.00 Å
# [✓] Updated Mn → rcut = 3.75 Å
# [✓] Updated V → rcut = 4.00 Å
# [✓] Updated Re → rcut = 3.50 Å
# [✓] Updated Cd → rcut = 3.75 Å
# [✓] Updated Nb → rcut = 3.50 Å
# [✓] Updated Cu → rcut = 4.25 Å
# [✓] Updated Ba → rcut = 6.50 Å
# [✓] Updated Pd → rcut = 4.25 Å
# [✓] Updated Se → rcut = 3.50 Å
# [✓] Updated Ni → rcut = 4.50 Å
# [✓] Updated C → rcut = 2.00 Å
# [✓] Updated Sr → rcut = 5.75 Å
# [✓] Updated Os → rcut = 3.25 Å
# [✓] Updated Rb → rcut = 7.25 Å
# [✓] Updated K → rcut = 7.00 Å
# [✓] Updated Cr → rcut = 3.50 Å
# [✓] Updated Te → rcut = 3.50 Å

# %%
! rm -r combined_plots
# Out:
# rm: cannot remove 'combined_plots': No such file or directory

# %%
import os
import shutil

# Source and destination base paths
src_dir = "/global/cfs/cdirs/m4597/Suvo/GAP_all/Normal_Modes/combined_plots"
dst_base = "/global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots"

# Loop through all source files
for fname in os.listdir(src_dir):
    if fname.endswith("_nmode_combined.png"):
        element = fname.split("_")[0]
        src = os.path.join(src_dir, fname)
        dst_folder = os.path.join(dst_base, element)
        dst = os.path.join(dst_folder, "NM.png")

        os.makedirs(dst_folder, exist_ok=True)
        shutil.copy(src, dst)
        print(f"[✓] {element}: Copied to {dst}")
# Out:
# [✓] Tl: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Tl/NM.png
# [✓] Re: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Re/NM.png
# [✓] Pt: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pt/NM.png
# [✓] Na: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Na/NM.png
# [✓] Ge: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ge/NM.png
# [✓] Cu: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cu/NM.png
# [✓] Nb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Nb/NM.png
# [✓] Ag: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ag/NM.png
# [✓] Rh: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Rh/NM.png
# [✓] W: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/W/NM.png
# [✓] Se: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Se/NM.png
# [✓] Fe: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Fe/NM.png
# [✓] Sb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sb/NM.png
# [✓] Y: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Y/NM.png
# [✓] Ru: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ru/NM.png
# [✓] Ca: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ca/NM.png
# [✓] Zr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Zr/NM.png
# [✓] Ir: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ir/NM.png
# [✓] Te: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Te/NM.png
# [✓] Pb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pb/NM.png
# [✓] S: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/S/NM.png
# [✓] B: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/B/NM.png
# [✓] Cd: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cd/NM.png
# [✓] Mo: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mo/NM.png
# [✓] Sr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sr/NM.png
# [✓] Co: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Co/NM.png
# [✓] Si: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Si/NM.png
# [✓] K: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/K/NM.png
# [✓] Li: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Li/NM.png
# [✓] Mg: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mg/NM.png
# [✓] Ga: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ga/NM.png
# [✓] Zn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Zn/NM.png
# [✓] Hf: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Hf/NM.png
# [✓] Ba: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ba/NM.png
# [✓] Mn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mn/NM.png
# [✓] Ta: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ta/NM.png
# [✓] Ni: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ni/NM.png
# [✓] Sn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sn/NM.png
# [✓] Sc: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sc/NM.png
# [✓] V: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/V/NM.png
# [✓] Be: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Be/NM.png
# [✓] P: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/P/NM.png
# [✓] Cs: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cs/NM.png
# [✓] Bi: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Bi/NM.png
# [✓] Pd: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pd/NM.png
# [✓] Ti: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ti/NM.png
# [✓] C: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/C/NM.png
# [✓] Cr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cr/NM.png
# [✓] Al: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Al/NM.png
# [✓] Os: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Os/NM.png
# [✓] In: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/In/NM.png
# [✓] Rb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Rb/NM.png
# [✓] As: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/As/NM.png
# [✓] Au: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Au/NM.png

# %%
import os
import shutil

# Source and destination base paths
src_dir = "/global/cfs/cdirs/m4597/Suvo/GAP_all/Dynamics/rmsd_plots"
dst_base = "/global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots"

# Loop through all source files
for fname in os.listdir(src_dir):
    if fname.endswith("_rmsd_vs_time.png"):
        element = fname.split("_")[0]
        src = os.path.join(src_dir, fname)
        dst_folder = os.path.join(dst_base, element)
        dst = os.path.join(dst_folder, "dynamics.png")

        os.makedirs(dst_folder, exist_ok=True)
        shutil.copy(src, dst)
        print(f"[✓] {element}: Copied to {dst}")
# Out:
# [✓] Pt: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pt/dynamics.png
# [✓] Ta: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ta/dynamics.png
# [✓] B: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/B/dynamics.png
# [✓] Ru: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ru/dynamics.png
# [✓] V: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/V/dynamics.png
# [✓] Si: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Si/dynamics.png
# [✓] Nb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Nb/dynamics.png
# [✓] Tl: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Tl/dynamics.png
# [✓] Mn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mn/dynamics.png
# [✓] Sb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sb/dynamics.png
# [✓] Se: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Se/dynamics.png
# [✓] Cd: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cd/dynamics.png
# [✓] Zr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Zr/dynamics.png
# [✓] Ga: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ga/dynamics.png
# [✓] Ni: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ni/dynamics.png
# [✓] Rb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Rb/dynamics.png
# [✓] Na: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Na/dynamics.png
# [✓] Pd: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pd/dynamics.png
# [✓] Fe: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Fe/dynamics.png
# [✓] Sn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sn/dynamics.png
# [✓] Y: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Y/dynamics.png
# [✓] Zn: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Zn/dynamics.png
# [✓] In: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/In/dynamics.png
# [✓] Ir: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ir/dynamics.png
# [✓] Li: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Li/dynamics.png
# [✓] Ti: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ti/dynamics.png
# [✓] Al: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Al/dynamics.png
# [✓] As: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/As/dynamics.png
# [✓] Mg: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mg/dynamics.png
# [✓] Be: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Be/dynamics.png
# [✓] Hf: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Hf/dynamics.png
# [✓] Mo: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Mo/dynamics.png
# [✓] Bi: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Bi/dynamics.png
# [✓] Ba: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ba/dynamics.png
# [✓] Cs: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cs/dynamics.png
# [✓] Re: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Re/dynamics.png
# [✓] Co: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Co/dynamics.png
# [✓] Ag: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ag/dynamics.png
# [✓] Os: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Os/dynamics.png
# [✓] S: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/S/dynamics.png
# [✓] Sr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sr/dynamics.png
# [✓] Rh: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Rh/dynamics.png
# [✓] W: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/W/dynamics.png
# [✓] Sc: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Sc/dynamics.png
# [✓] Pb: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Pb/dynamics.png
# [✓] C: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/C/dynamics.png
# [✓] Au: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Au/dynamics.png
# [✓] Te: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Te/dynamics.png
# [✓] Cu: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cu/dynamics.png
# [✓] P: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/P/dynamics.png
# [✓] Ca: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ca/dynamics.png
# [✓] Cr: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Cr/dynamics.png
# [✓] Ge: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/Ge/dynamics.png
# [✓] K: Copied to /global/cfs/cdirs/m4597/Suvo/GAP_all/Periodic_Table_HTML/plots/K/dynamics.png

# %%
import os
import re

# Path to the folder containing your HTML pages
pages_dir = "pages"

# Regex pattern to match the dataset download block
pattern = re.compile(
    r'<div class="column">\s*<a href="datasets/.*?\.xyz" class="download-btn dataset">Dataset</a>\s*</div>',
    re.DOTALL
)

# Loop over each file in the directory
for filename in os.listdir(pages_dir):
    if filename.endswith(".html"):
        filepath = os.path.join(pages_dir, filename)
        with open(filepath, 'r', encoding='utf-8') as file:
            content = file.read()

        # Remove the dataset download block
        modified_content = pattern.sub('', content)

        # Write the modified content back to the file
        with open(filepath, 'w', encoding='utf-8') as file:
            file.write(modified_content)

        print(f"Updated: {filename}")
# Out:
# Updated: Sb.html
# Updated: In.html
# Updated: P.html
# Updated: Tl.html
# Updated: W.html
# Updated: Sn.html
# Updated: Zn.html
# Updated: Ga.html
# Updated: Na.html
# Updated: Al.html
# Updated: Be.html
# Updated: Si.html
# Updated: Ag.html
# Updated: Co.html
# Updated: Hf.html
# Updated: Mo.html
# Updated: As.html
# Updated: Ti.html
# Updated: Fe.html
# Updated: S.html
# Updated: B.html
# Updated: Ir.html
# Updated: Au.html
# Updated: Rh.html
# Updated: Zr.html
# Updated: Ge.html
# Updated: Ru.html
# Updated: Bi.html
# Updated: Mg.html
# Updated: Cs.html
# Updated: Ca.html
# Updated: Li.html
# Updated: Y.html
# Updated: Ta.html
# Updated: Pt.html
# Updated: Pb.html
# Updated: Sc.html
# Updated: Mn.html
# Updated: V.html
# Updated: Re.html
# Updated: Cd.html
# Updated: Nb.html
# Updated: Cu.html
# Updated: Ba.html
# Updated: Pd.html
# Updated: Se.html
# Updated: Ni.html
# Updated: C.html
# Updated: Sr.html
# Updated: Os.html
# Updated: Rb.html
# Updated: K.html
# Updated: Cr.html
# Updated: Te.html
